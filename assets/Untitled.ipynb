# %%
# %load markov_debate.py

import markovify
import pandas as pd
import nltk


def csv_to_string(input_csv, speaker):
    """
    Extract text from csv; put into string for a speaker
    
    param: input_csv: (string) path to csv file
    param: speaker: (string) name of speaker to search for in csv
    return: (string) speaker_text string of text corresponding to a speaker
    """

    debate_csv = pd.read_csv(input_csv)
    debate_speaker = debate_csv[debate_csv["Speaker"] == speaker]["Text"]

    speaker_text = ""
    for line in debate_speaker:
        speaker_text += line

    return speaker_text


def string_to_markov_chains(input_string):
    """
    Create a markov chain from a string of text
     
    param: (string) input_string 
    return: a markovify object
    """

    markov_chain = markovify.Text(input_string)
    
    return markov_chain


def generate_banter(markov_ch_1, markov_ch_2, speaker_name_1, speaker_name_2, short_sentence = True, sentence_size = 140):

    return_banter = ""

    if short_sentence:
        short_speaker_1 = markov_ch_1.make_short_sentence(sentence_size)
        short_speaker_2 = markov_ch_2.make_short_sentence(sentence_size)

        return_banter += "{}: ".format(speaker_name_1) + short_speaker_1 + "\n" + "{}: ".format(speaker_name_2) + short_speaker_2 + "\n"

    else:
        speaker_1_sentence = markov_ch_1.make_sentence()
        speaker_2_sentence = markov_ch_2.make_sentence()

        return_banter += "{}: ".format(speaker_name_1) + speaker_1_sentence + "\n" + "{}: ".speaker_name_2 + speaker_2_sentence + "\n"

    return return_banter


def banter(num_lines, markov_ch_1, markov_ch_2, speaker_name_1, speaker_name_2, short_sentence=True,
           sentence_size=140, **kwargs):
    """
    Todo: Generate rebuttal based on topic/s from previous sentence for semblence of flow\
    Extract nouns/get rid of closed-class words from first generated sentence; 
    Generate next sentence (rebuttal) based on nouns/topics from previous;
    """
    topics = kwargs.get('topics')
    return_banter = ""

    if topics:
        for topic in topics:
            print ("Round Topic: {0}").format(topic)
            for i in range(num_lines):
                banter = str(generate_banter(markov_ch_1, markov_ch_2, speaker_name_1, speaker_name_2, 
                                             short_sentence, sentence_size))
                return_banter += banter + "\n"
    else:
        for i in range(num_lines):
                banter = str(generate_banter(markov_ch_1, markov_ch_2, speaker_name_1, speaker_name_2, 
                                             short_sentence, sentence_size))
                return_banter += banter + "\n"

    return ("\n" + return_banter)


def main():
    input_csv = "./debate.csv"
    clinton_text = csv_to_string(input_csv, "Clinton")
    trump_text = csv_to_string(input_csv, "Trump")
    
    clinton_markov = string_to_markov_chains(clinton_text)
    trump_markov = string_to_markov_chains(trump_text)
    
    print generate_banter(clinton_markov, trump_markov, "Clinton", "Trump")
    print banter(4, clinton_markov, trump_markov, "Clinton", "Trump")
    
    return
 
#banter(1, topics = ["Race", "Grace", "Mace"])

#sentence = markov_clinton.make_sentence()
#test = nltk.word_tokenize(sentence)

#nltk.pos_tag(sentence)

#nltk.word_tokenize() nltk.tokenize()




# In[ ]:

# %%
main()
# Out:
# Clinton: So we know we've got to get those costs down.
# Trump: Believe me, he's not a good job and a great land.
#
# Round Topic: Race
#
# Clinton: After a year-long investigation, there is a plan that Donald talks a lot of refugees, but to, frankly, gain some leverage over them.
# Trump: She's telling us how to defeat ISIS.
#
# Clinton: That is not the case in a big red flag waving for ISIS to reconstitute itself.
# Trump: 600 -- wait one second.
#
# Clinton: The entire press corps has looked at both of our police are outgunned.
# Trump: They're coming in from Syria.
#
# Clinton: And the Affordable Care Act.
# Trump: And I'm very, very serious trouble, because we have to repeal it and nobody feels sorry for her.

# %%
main()
# Out:
# Clinton: Most of the people on Medicaid.
# Trump: And foreign companies are now against us.
#
#
# Clinton: I personally believe that he's trying to do so.
# Trump: You know that, because they know my business say, boy, that's really what's going on.
#
# Clinton: And I do not think that that's a good middle-class life for us, but the people who understand the way Republicans are leaving you.
# Trump: But we have a conservative bent.
#
# Clinton: You know, President Obama got a treaty reducing nuclear weapons.
# Trump: She has been let down by our country.
#
# Clinton: They've looked at what Donald is proposing with these massive tax cuts we've ever had.
# Trump: Because look at her website.She's going to stop them?
